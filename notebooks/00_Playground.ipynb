# %%
print("Welcome Gladiator")
# Out:
# Welcome Gladiator

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.9.0

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Display options
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)

# Random seed
RANDOM_STATE = 42
