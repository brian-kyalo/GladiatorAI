# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(
        0,
        str(PROJECT_ROOT)
    )

print("Project root:", PROJECT_ROOT)
# Out:
# Project root: c:\Users\user\GladiatorAI

# %%
from ml.baseline import train_baseline

# %%
dataset_path = (
    "datasets/processed/"
    "gladiator_training.csv"
)

result = train_baseline(
    dataset_path
)

# %%
print("=" * 70)
print("GLADIATOR AI — BASELINE MODEL")
print("=" * 70)

print(
    f"\nTraining rows : {result.train_rows}"
)

print(
    f"Test rows     : {result.test_rows}"
)

print(
    f"Cutoff date   : {result.cutoff_date.date()}"
)

print("\nMETRICS")
print("-" * 70)

print(
    f"Accuracy           : "
    f"{result.evaluation.accuracy:.4f}"
)

print(
    f"Balanced Accuracy  : "
    f"{result.evaluation.balanced_accuracy:.4f}"
)

print(
    f"ROC-AUC            : "
    f"{result.evaluation.roc_auc:.4f}"
)

print(
    f"Log Loss           : "
    f"{result.evaluation.log_loss_value:.4f}"
)

print("\nCONFUSION MATRIX")
print("-" * 70)

print(
    result.evaluation.confusion_matrix
)
